# %%
import utils
import numpy as np
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import axes3d

# %%
phi = np.linspace(0, np.pi, 20)
theta = np.linspace(0, 2 * np.pi, 40)
x = np.outer(np.sin(theta), np.cos(phi))
y = np.outer(np.sin(theta), np.sin(phi))
z = np.outer(np.cos(theta), np.ones_like(phi))

xi, yi, zi = utils.sample_spherical(np.array([0.25, 0.25, 0.25]), 100, scale=0.5)

fig, ax = plt.subplots(1, 1, subplot_kw={'projection': '3d', 'aspect': 'equal'})
ax.plot_wireframe(x, y, z, color='k', rstride=1, cstride=1)
ax.scatter(xi, yi, zi, s=100, c='r', zorder=10)

# %%
xi.shape
# Out:
# (100,)

# %%
utils.sample_spherical((3, 3, 3), 100) + np.array([[3],[3],[3]])
# Out:
# array([[2.97229588, 2.99832786, 3.00692777, 2.9847133 , 2.99299986,
#         2.99709722, 2.98540153, 2.99307655, 2.96252283, 2.96320193,
#         3.0383505 , 3.01984648, 3.00319476, 3.03498055, 2.98080083,
#         3.042184  , 3.00144577, 3.00494022, 2.99639373, 3.00180053,
#         2.99517758, 2.95319924, 3.01416167, 3.03926548, 2.98608483,
#         3.00784231, 3.03566112, 3.00129255, 3.03110564, 3.02435086,
#         3.00721844, 2.96965239, 2.99848247, 3.01235949, 3.01386718,
#         3.03764391, 3.01730141, 2.99320169, 3.0098563 , 2.95751699,
#         2.9841118 , 2.99220528, 3.03861799, 2.99518998, 3.04867309,
#         2.9811522 , 2.95280398, 2.99638963, 2.97025302, 3.03953838,
#         3.01367955, 3.04762137, 3.04122621, 3.0297028 , 3.03116768,
#         2.99704665, 2.95696207, 2.96267127, 3.02215568, 2.95995087,
#         2.95008401, 3.00001579, 3.01952923, 2.95250747, 2.95343934,
#         2.99378167, 3.02406721, 3.03694229, 2.99035501, 3.02240786,
# ...

# %%
import roboticstoolbox as rtb

x = rtb.models.DH.Puma560().fkine(rtb.models.DH.Puma560().qr)

# %%
x.t
# Out:
# array([ 0.0203 , -0.15005,  1.53543])

# %%
from robot_cspace import RobotCSpace

# %%
RobotCSpace([(0, 25), (0, 25), (0, 25), (0, 25)], 5)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 RobotCSpace([(0, 25), (0, 25), (0, 25), (0, 25)], 5)
#
# File ~\CS4610\Torquee\src\robot_cspace.py:9, in RobotCSpace.__init__(self, joint_limits, step_size)
#       7 self.step_size = step_size
#       8 self.num_cells = [int(np.ceil((limit[1] - limit[0]) / step_size)) + 1 for limit in joint_limits]
# ----> 9 self.grid = self.create_grid()
#
# File ~\CS4610\Torquee\src\robot_cspace.py:20, in RobotCSpace.create_grid(self)
#      18 # Set corresponding grid cells to True
#      19 if upper_index >= lower_index:
# ---> 20     grid[(slice(None),) * i + tuple(range(lower_index, upper_index + 1))] = True
#      21 else:
#      22     grid[(slice(None),) * i + tuple(range(lower_index, self.num_cells[i]))] = True
#
# IndexError: too many indices for array: array is 4-dimensional, but 6 were indexed
